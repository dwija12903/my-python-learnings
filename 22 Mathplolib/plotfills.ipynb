# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('data1.csv')
ages=data['Age']
dev=data['All_Devs']
python=data['Python']
js=data['JavaScript']
plt.plot(dev,ages)
plt.fill_between(python,ages,alpha=0.25)
plt.show()
